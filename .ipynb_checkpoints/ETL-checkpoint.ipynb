# %%
# importing dependencies

import pandas as pd

# %% [markdown]
# # Cleaning of car_data.csv

# %%
# Read Csv file

car_data = pd.read_csv("Resources/car_data.csv")
car_data.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
# Keep only columns we need

car_df = car_data[["Make", "Model", "Year"]]
car_df.head(15)
# Out:
#    Make       Model  Year
# 0   BMW  1 Series M  2011
# 1   BMW    1 Series  2011
# 2   BMW    1 Series  2011
# 3   BMW    1 Series  2011
# 4   BMW    1 Series  2011
# 5   BMW    1 Series  2012
# 6   BMW    1 Series  2012
# 7   BMW    1 Series  2012
# 8   BMW    1 Series  2012
# 9   BMW    1 Series  2013
# 10  BMW    1 Series  2013
# 11  BMW    1 Series  2013
# 12  BMW    1 Series  2013
# 13  BMW    1 Series  2013
# 14  BMW    1 Series  2013

# %%
# Our goal is to find cars 2015, 2016, 2017 years of manufacture

updated_car_df = car_df[(car_df.Year == 2015) | (car_df.Year == 2016) | (car_df.Year == 2017)]
updated_car_df
# Out:
#            Make       Model  Year
# 32         FIAT  124 Spider  2017
# 33         FIAT  124 Spider  2017
# 34         FIAT  124 Spider  2017
# 41          BMW    2 Series  2016
# 42          BMW    2 Series  2016
# 43          BMW    2 Series  2016
# 44          BMW    2 Series  2016
# 45          BMW    2 Series  2016
# 46          BMW    2 Series  2016
# 47          BMW    2 Series  2016
# 48          BMW    2 Series  2016
# 49          BMW    2 Series  2016
# 50          BMW    2 Series  2017
# 51          BMW    2 Series  2017
# 52          BMW    2 Series  2017
# 53          BMW    2 Series  2017
# 54          BMW    2 Series  2017
# 55          BMW    2 Series  2017
# 56          BMW    2 Series  2017
# 57          BMW    2 Series  2017
# 64     Chrysler         200  2015
# 65     Chrysler         200  2015
# 66     Chrysler         200  2015
# 67     Chrysler         200  2015
# 68     Chrysler         200  2015
# 69     Chrysler         200  2015
# 70     Chrysler         200  2016
# 71     Chrysler         200  2016
# 72     Chrysler         200  2016
# 73     Chrysler         200  2016
# ...         ...         ...   ...
# 11857       GMC    Yukon XL  2017
# 11858       GMC    Yukon XL  2017
# 11859       GMC    Yukon XL  2017
# 11860       GMC    Yukon XL  2017
# 11861       GMC    Yukon XL  2017
# 11862       GMC    Yukon XL  2017
# 11863       GMC       Yukon  2015
# 11864       GMC       Yukon  2015
# 11865       GMC       Yukon  2015
# 11866       GMC       Yukon  2015
# 11867       GMC       Yukon  2015
# 11868       GMC       Yukon  2015
# 11869       GMC       Yukon  2016
# 11870       GMC       Yukon  2016
# 11871       GMC       Yukon  2016
# 11872       GMC       Yukon  2016
# 11873       GMC       Yukon  2016
# 11874       GMC       Yukon  2016
# 11875       GMC       Yukon  2017
# 11876       GMC       Yukon  2017
# 11877       GMC       Yukon  2017
# 11878       GMC       Yukon  2017
# 11879       GMC       Yukon  2017
# 11880       GMC       Yukon  2017
# 11897       BMW          Z4  2015
# 11898       BMW          Z4  2015
# 11899       BMW          Z4  2015
# 11900       BMW          Z4  2016
# 11901       BMW          Z4  2016
# 11902       BMW          Z4  2016
#
# [5995 rows x 3 columns]

# %%
# Drop duplicates to show all unique Models of each car manufactured in 2015, 2016 and 2017 years

updated_car_database = updated_car_df[["Make"]]
final_car_database = updated_car_database.drop_duplicates(['Make'], keep = 'last').sort_values(["Make"], ascending= True)
final_car_database
# Out:
#                 Make
# 10509          Acura
# 478       Alfa Romeo
# 11213   Aston Martin
# 10902           Audi
# 11902            BMW
# 7023         Bentley
# 11320          Buick
# 11791       Cadillac
# 10786      Chevrolet
# 10566       Chrysler
# 11393          Dodge
# 597             FIAT
# 4668         Ferrari
# 10738           Ford
# 11880            GMC
# 5204         Genesis
# 8509           Honda
# 11245        Hyundai
# 7955        Infiniti
# 9935             Kia
# 5777     Lamborghini
# 8328      Land Rover
# 8694           Lexus
# 7166         Lincoln
# 4258           Lotus
# 7900        Maserati
# 7127           Mazda
# 704          McLaren
# 9686   Mercedes-Benz
# 7397      Mitsubishi
# 11764         Nissan
# 7436         Porsche
# 11450    Rolls-Royce
# 11550          Scion
# 11808         Subaru
# 6938           Tesla
# 11831         Toyota
# 10549     Volkswagen
# 11639          Volvo

# %%
missing_data = pd.DataFrame({"Make": ["Jaguar", "Jeep", "MINI", "Smart"]})
final_car_updated = final_car_database.append(missing_data)

# %%
make_df = final_car_updated.sort_values(["Make"], ascending = True)

make = make_df[make_df.Make != "Lotus"]
make = make[make.Make != "Scion"]

make
# Out:
#                 Make
# 10509          Acura
# 478       Alfa Romeo
# 11213   Aston Martin
# 10902           Audi
# 11902            BMW
# 7023         Bentley
# 11320          Buick
# 11791       Cadillac
# 10786      Chevrolet
# 10566       Chrysler
# 11393          Dodge
# 597             FIAT
# 4668         Ferrari
# 10738           Ford
# 11880            GMC
# 5204         Genesis
# 8509           Honda
# 11245        Hyundai
# 7955        Infiniti
# 0             Jaguar
# 1               Jeep
# 9935             Kia
# 5777     Lamborghini
# 8328      Land Rover
# 8694           Lexus
# 7166         Lincoln
# 2               MINI
# 7900        Maserati
# 7127           Mazda
# 704          McLaren
# 9686   Mercedes-Benz
# 7397      Mitsubishi
# 11764         Nissan
# 7436         Porsche
# 11450    Rolls-Royce
# 3              Smart
# 11808         Subaru
# 6938           Tesla
# 11831         Toyota
# 10549     Volkswagen
# 11639          Volvo

# %% [markdown]
# # Cleaning of used_cars.csv

# %%
# Reading used_cars.csv file

used_car_data = pd.read_csv("Resources/used_cars.csv", error_bad_lines=False, warn_bad_lines = False)
used_car_data.head(20)
# Out:
#     Id  Price  Year  Mileage            City State                Vin   Make  \
# 0    1  16472  2015    18681  Jefferson City    MO  KL4CJBSBXFB267643  Buick
# 1    2  15749  2015    27592        Highland    IN  KL4CJASB5FB245057  Buick
# 2    3  16998  2015    13650           Boone    NC  KL4CJCSB0FB264921  Buick
# 3    4  15777  2015    25195     New Orleans    LA  KL4CJASB4FB217542  Buick
# 4    5  16784  2015    22800       Las Vegas    NV  KL4CJBSB3FB166881  Buick
# 5    6  17020  2016    16877    Grand Island    NY  KL4CJASB7GB536760  Buick
# 6    7  15950  2015    27885     West Covina    CA  KL4CJASB3FB241802  Buick
# 7    8  17091  2016    24008     Little Rock    AR  KL4CJASBXGB565542  Buick
# 8    9  16995  2015     8624     Punta Gorda    FL  KL4CJFSB7FB173565  Buick
# 9   10  17700  2015    13807    Jacksonville    NC  KL4CJBSB8FB068543  Buick
# 10  11  14555  2014    29535         Phoenix    AZ  KL4CJASB3EB786106  Buick
# 11  12  18988  2017     4705   Bowling Green    KY  KL4CJASB7HB035630  Buick
# 12  13  17491  2016    11123         Memphis    TN  KL4CJASBXGB720588  Buick
# 13  14  17432  2015    11330      St. Peters    MO  KL4CJBSB0FB117931  Buick
# 14  15  20959  2017    36981          Taylor    MI  1G4PR5SK9H4108021  Buick
# 15  16  16699  2015    21323      Clearwater    FL  KL4CJASB2FB127080  Buick
# 16  17  15995  2015    18887        Metairie    LA  KL4CJASB8FB267196  Buick
# 17  18  17950  2016    10925       Lafayette    IN  KL4CJASB4GB519690  Buick
# 18  19  15239  2015    20681          Dallas    TX  KL4CJBSB2FB179802  Buick
# 19  20  16814  2015    11541     Gainesville    FL  KL4CJASB0FB248111  Buick
#
#                 Model
# 0   EncoreConvenience
# 1           EncoreFWD
# 2       EncoreLeather
# 3           EncoreFWD
# 4   EncoreConvenience
# 5           EncoreFWD
# 6           EncoreFWD
# 7           EncoreFWD
# 8   EncoreConvenience
# 9   EncoreConvenience
# 10          EncoreFWD
# 11          EncoreFWD
# 12          EncoreFWD
# 13  EncoreConvenience
# 14        VeranoSport
# 15          EncoreFWD
# 16          EncoreFWD
# 17          EncoreFWD
# 18  EncoreConvenience
# 19          EncoreFWD

# %%
# Keep only columns we need

used_car_df = used_car_data[["Make", "Model", "Year", "Price"]]
used_car_df.head()
# Out:
#     Make              Model  Year  Price
# 0  Buick  EncoreConvenience  2015  16472
# 1  Buick          EncoreFWD  2015  15749
# 2  Buick      EncoreLeather  2015  16998
# 3  Buick          EncoreFWD  2015  15777
# 4  Buick  EncoreConvenience  2015  16784

# %%
# Change format of "Price"

# used_car_df['Price'] = used_car_df['Price'].apply(lambda x: "{:,}".format(x))

# %%
#wrong_price = used_car_df.loc[used_car_df["Price"] == 99999]
#wrong_price

# %% [markdown]
# # Data Cleaning

# %%
# remove all rows with 99999 price 

updated_used_df = used_car_df[used_car_df.Price != 99999]

# %%
# Rename incorrect Makes

updated_used_df["Make"] = updated_used_df["Make"].replace({"Alfa":"Alfa Romeo", "Aston": "Aston Martin", "INFINITI": "Infiniti",
                                                          "Land": "Land Rover", "Ram": "Dodge", "smart": "Smart"})

updated_used_df
# Out:
# C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#           Make              Model  Year  Price
# 0        Buick  EncoreConvenience  2015  16472
# 1        Buick          EncoreFWD  2015  15749
# 2        Buick      EncoreLeather  2015  16998
# 3        Buick          EncoreFWD  2015  15777
# 4        Buick  EncoreConvenience  2015  16784
# 5        Buick          EncoreFWD  2016  17020
# 6        Buick          EncoreFWD  2015  15950
# 7        Buick          EncoreFWD  2016  17091
# 8        Buick  EncoreConvenience  2015  16995
# 9        Buick  EncoreConvenience  2015  17700
# 10       Buick          EncoreFWD  2014  14555
# 11       Buick          EncoreFWD  2017  18988
# 12       Buick          EncoreFWD  2016  17491
# 13       Buick  EncoreConvenience  2015  17432
# 14       Buick        VeranoSport  2017  20959
# 15       Buick          EncoreFWD  2015  16699
# 16       Buick          EncoreFWD  2015  15995
# 1216190  Volvo               XC90  2016  59990
# 1216191  Volvo            XC90AWD  2016  48995
# 1216199  Volvo            XC90AWD  2016  53775
# 1216202  Volvo               XC90  2016  62886
# 1216204  Volvo               XC90  2016  63586
# 1216207  Volvo            XC90AWD  2016  52427
# 1216209  Volvo               XC90  2016  49390
# 1216212  Volvo            XC90AWD  2016  52700
# 1216215  Volvo              S60T5  2016  44565
# 1216223  Volvo               XC90  2016  68700
# 1216227  Volvo               XC90  2016  67990
# 1216231  Volvo            XC90AWD  2016  59900
# 1216236  Volvo               XC90  2016  54900
#
# [189032 rows x 4 columns]

# %%
# Counting average price for each Make manufactured in 2016

avg_price_2016 = updated_used_car_dataframe_2016.groupby("Make").mean()
avg_price_2016

average_price_2016 = avg_price_2016.reset_index()
average_price_2016
# Out:
#              Make    Year          Price
# 0           Acura  2016.0   34235.929682
# 1      Alfa Romeo  2016.0   58792.200000
# 2    Aston Martin  2016.0  146755.285714
# 3            Audi  2016.0   37903.676543
# 4             BMW  2016.0   35550.730271
# 5         Bentley  2016.0  187018.000000
# 6           Buick  2016.0   23857.868509
# 7        Cadillac  2016.0   43599.923801
# 8       Chevrolet  2016.0   26838.810731
# 9        Chrysler  2016.0   18749.031613
# 10          Dodge  2016.0   23414.219379
# 11           FIAT  2016.0   15710.660279
# 12        Ferrari  2016.0  274799.723404
# 13           Ford  2016.0   25263.602106
# 14            GMC  2016.0   37014.861648
# 15          Honda  2016.0   23854.490683
# 16        Hyundai  2016.0   15017.113020
# 17       Infiniti  2016.0   37187.593700
# 18         Jaguar  2016.0   56029.599303
# 19           Jeep  2016.0   22532.647854
# 20            Kia  2016.0   17103.948495
# 21    Lamborghini  2016.0  259106.363636
# 22     Land Rover  2016.0   61978.033684
# 23          Lexus  2016.0   40002.640190
# 24        Lincoln  2016.0   32092.722843
# 25           MINI  2016.0   22540.769784
# 26       Maserati  2016.0   64937.705357
# 27          Mazda  2016.0   21050.950395
# 28        McLaren  2016.0  280722.526316
# 29  Mercedes-Benz  2016.0   45346.637773
# 30     Mitsubishi  2016.0   15392.950218
# 31         Nissan  2016.0   18137.848493
# 32        Porsche  2016.0   84530.087393
# 33    Rolls-Royce  2016.0  298873.000000
# 34          Scion  2016.0   15377.101449
# 35          Smart  2016.0   12579.541096
# 36         Subaru  2016.0   24058.630086
# 37          Tesla  2016.0   88162.643836
# 38         Toyota  2016.0   23398.863328
# 39     Volkswagen  2016.0   17257.009619
# 40          Volvo  2016.0   37139.681473

# %% [markdown]
# # AVG 2017

# %%
# Retrieving only 2017 data

updated_used_car_dataframe_2017 = final_changes_used[(final_changes_used.Year == 2017)]
updated_used_car_dataframe_2017
# Out:
#           Make         Model  Year  Price
# 11       Buick     EncoreFWD  2017  18988
# 14       Buick   VeranoSport  2017  20959
# 25       Buick     EncoreFWD  2017  18902
# 26       Buick     EncoreFWD  2017  18902
# 34       Buick     EncoreFWD  2017  18988
# 39       Buick     EncoreFWD  2017  17900
# 58       Buick     EncoreFWD  2017  20500
# 61       Buick     EncoreFWD  2017  18991
# 88       Buick     EncoreFWD  2017  19327
# 15        Genesis  2017.0   44752.591133
# 16          Honda  2017.0   24582.065713
# 17        Hyundai  2017.0   16986.184570
# 18       Infiniti  2017.0   39695.698475
# 19         Jaguar  2017.0   48242.928177
# 20           Jeep  2017.0   26717.159547
# 21            Kia  2017.0   19207.082491
# 22    Lamborghini  2017.0  257657.090909
# 23     Land Rover  2017.0   51247.864769
# 24          Lexus  2017.0   46129.284483
# 25        Lincoln  2017.0   36727.833711
# 26           MINI  2017.0   28501.183391
# 27       Maserati  2017.0   71353.390411
# 28          Mazda  2017.0   21952.065112
# 29        McLaren  2017.0  191504.833333
# 30  Mercedes-Benz  2017.0   49400.609952
# 31     Mitsubishi  2017.0   16152.412109
# 32         Nissan  2017.0   23757.871535
# 33        Porsche  2017.0   82670.502276
# 34    Rolls-Royce  2017.0  310427.500000
# 35          Smart  2017.0   18346.818182
# 36         Subaru  2017.0   26796.185990
# 37          Tesla  2017.0   90739.500000
# 38         Toyota  2017.0   24630.226054
# 39     Volkswagen  2017.0   21404.324066
# 40          Volvo  2017.0   36505.424264

# %% [markdown]
# # AVG 2018

# %%
# updated_used_car_dataframe_2018 = final_changes_used[(final_changes_used.Year == 2018)]
# updated_used_car_dataframe_2018

# %% [markdown]
# # Fixing and Representing all tables we will use for SQL

# %%
# Renaming columns of our dataframes

make = make.rename(columns = {"Make": "make"})
average_price_2015 = average_price_2015.rename(columns = {"Make": "make", "Year": "year", "Price": "price"})
average_price_2016 = average_price_2016.rename(columns = {"Make": "make", "Year": "year", "Price": "price"})
average_price_2017 = average_price_2017.rename(columns = {"Make": "make", "Year": "year", "Price": "price"})

# %%
# Adding unique id column to our dataframes

make['id'] = range(1, 1+len(make))
updated_make = make[["id", "make"]]

average_price_2015['id'] = range(1, 1+len(average_price_2015))
updated_average_price_2015 = average_price_2015[["id", "make", "year", "price"]]

average_price_2016['id'] = range(1, 1+len(average_price_2016))
updated_average_price_2016 = average_price_2016[["id", "make", "year", "price"]]

average_price_2017['id'] = range(1, 1+len(average_price_2017))
updated_average_price_2017 = average_price_2017[["id", "make", "year", "price"]]

# %%
# Had to make some more cleaning
# Removing "Genesis" Make

final_make = updated_make[updated_make.make != "Genesis"]
final_make
# Out:
#        id           make
# 10509   1          Acura
# 478     2     Alfa Romeo
# 11213   3   Aston Martin
# 10902   4           Audi
# 11902   5            BMW
# 7023    6        Bentley
# 11320   7          Buick
# 11791   8       Cadillac
# 10786   9      Chevrolet
# 10566  10       Chrysler
# 11393  11          Dodge
# 597    12           FIAT
# 4668   13        Ferrari
# 10738  14           Ford
# 11880  15            GMC
# 8509   17          Honda
# 11245  18        Hyundai
# 7955   19       Infiniti
# 0      20         Jaguar
# 1      21           Jeep
# 9935   22            Kia
# 5777   23    Lamborghini
# 8328   24     Land Rover
# 8694   25          Lexus
# 7166   26        Lincoln
# 2      27           MINI
# 7900   28       Maserati
# 7127   29          Mazda
# 704    30        McLaren
# 9686   31  Mercedes-Benz
# 7397   32     Mitsubishi
# 11764  33         Nissan
# 7436   34        Porsche
# 11450  35    Rolls-Royce
# 3      36          Smart
# 11808  37         Subaru
# 6938   38          Tesla
# 21  22    Lamborghini  2016.0  259106.363636
# 22  23     Land Rover  2016.0   61978.033684
# 23  24          Lexus  2016.0   40002.640190
# 24  25        Lincoln  2016.0   32092.722843
# 25  26           MINI  2016.0   22540.769784
# 26  27       Maserati  2016.0   64937.705357
# 27  28          Mazda  2016.0   21050.950395
# 28  29        McLaren  2016.0  280722.526316
# 29  30  Mercedes-Benz  2016.0   45346.637773
# 30  31     Mitsubishi  2016.0   15392.950218
# 31  32         Nissan  2016.0   18137.848493
# 32  33        Porsche  2016.0   84530.087393
# 33  34    Rolls-Royce  2016.0  298873.000000
# 35  36          Smart  2016.0   12579.541096
# 36  37         Subaru  2016.0   24058.630086
# 37  38          Tesla  2016.0   88162.643836
# 38  39         Toyota  2016.0   23398.863328
# 39  40     Volkswagen  2016.0   17257.009619
# 40  41          Volvo  2016.0   37139.681473

# %%
# Removing "Genesis" Make

final_average_price_2017 = updated_average_price_2017[updated_average_price_2017.make != "Genesis"]
final_average_price_2017
# Out:
#     id           make    year          price
# 0    1          Acura  2017.0   39295.832329
# 1    2     Alfa Romeo  2017.0   53930.551724
# 2    3   Aston Martin  2017.0  211001.181818
# 3    4           Audi  2017.0   45149.046343
# 4    5            BMW  2017.0   42470.757483
# 5    6        Bentley  2017.0  217541.416667
# 6    7          Buick  2017.0   28850.887780
# 7    8       Cadillac  2017.0   42497.105854
# 8    9      Chevrolet  2017.0   26831.960955
# 9   10       Chrysler  2017.0   27538.476417
# 10  11          Dodge  2017.0   29006.735734
# 11  12           FIAT  2017.0   21832.569106
# 12  13        Ferrari  2017.0  332422.242424
# 13  14           Ford  2017.0   29228.390100
# 14  15            GMC  2017.0   37505.490472
# 16  17          Honda  2017.0   24582.065713
# 17  18        Hyundai  2017.0   16986.184570
# 18  19       Infiniti  2017.0   39695.698475
# 19  20         Jaguar  2017.0   48242.928177
# 20  21           Jeep  2017.0   26717.159547
# 21  22            Kia  2017.0   19207.082491
# 22  23    Lamborghini  2017.0  257657.090909
# 23  24     Land Rover  2017.0   51247.864769
# 24  25          Lexus  2017.0   46129.284483
# 25  26        Lincoln  2017.0   36727.833711
# 26  27           MINI  2017.0   28501.183391
# 27  28       Maserati  2017.0   71353.390411
# 28  29          Mazda  2017.0   21952.065112
# 29  30        McLaren  2017.0  191504.833333
# 30  31  Mercedes-Benz  2017.0   49400.609952
# 31  32     Mitsubishi  2017.0   16152.412109
# 32  33         Nissan  2017.0   23757.871535
# 33  34        Porsche  2017.0   82670.502276
# 34  35    Rolls-Royce  2017.0  310427.500000
# 35  36          Smart  2017.0   18346.818182
# 36  37         Subaru  2017.0   26796.185990
# 37  38          Tesla  2017.0   90739.500000
# 38  39         Toyota  2017.0   24630.226054
# 39  40     Volkswagen  2017.0   21404.324066
# 40  41          Volvo  2017.0   36505.424264

# %%
# REPRESENTING ALL TABLES WE WORKED ON


# final_make
# final_average_price_2015
# final_average_price_2016
# final_average_price_2017

# %% [markdown]
# # Connecting to SQL

# %%
# Import dependencies

from sqlalchemy import create_engine

# %%
# creating connection

connection_string = "postgres:postgres@localhost:5432/avg_car_prices"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables

engine.table_names()
# Out:
# ['make', 'avg_price_2015', 'avg_price_2016', 'avg_price_2017']

# %% [markdown]
# # Load DataFrames into database

# %%
final_make.to_sql(name = 'make', con = engine, if_exists = 'append', index = False)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1223                     self.dialect.do_executemany(
# -> 1224                         cursor, statement, parameters, context
#    1225                     )
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     751         else:
# --> 752             cursor.executemany(statement, parameters)
#     753
#
# IntegrityError: duplicate key value violates unique constraint "pk_make"
# DETAIL:  Key (make)=(Acura) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-32-45ecfd0cf7c1> in <module>
# ----> 1 final_make.to_sql(name = 'make', con = engine, if_exists = 'append', index = False)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2529         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2530                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2531                    dtype=dtype, method=method)
#    2532
#    2533     def to_pickle(self, path, compression='infer',
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     458     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     459                       index_label=index_label, schema=schema,
# --> 460                       chunksize=chunksize, dtype=dtype, method=method)
#     461
#     462
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1172                          schema=schema, dtype=dtype)
#    1173         table.create()
# -> 1174         table.insert(chunksize, method=method)
#    1175         if (not name.isdigit() and not name.islower()):
#    1176             # check for potentially case sensitivity issues (GH7815)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     684
#     685                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 686                 exec_insert(conn, keys, chunk_iter)
#     687
#     688     def _query_iterator(self, result, chunksize, columns, coerce_float=True,
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     597         """
#     598         data = [dict(zip(keys, row)) for row in data_iter]
# --> 599         conn.execute(self.table.insert(), data)
#     600
#     601     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     986             raise exc.ObjectNotExecutableError(object_)
#     987         else:
# --> 988             return meth(self, multiparams, params)
#     989
#     990     def _execute_function(self, func, multiparams, params):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     285     def _execute_on_connection(self, connection, multiparams, params):
#     286         if self.supports_execution:
# --> 287             return connection._execute_clauseelement(self, multiparams, params)
#     288         else:
#     289             raise exc.ObjectNotExecutableError(self)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1105             distilled_params,
#    1106             compiled_sql,
# -> 1107             distilled_params,
#    1108         )
#    1109         if self._has_events or self.engine._has_events:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1246         except BaseException as e:
#    1247             self._handle_dbapi_exception(
# -> 1248                 e, statement, parameters, cursor, context
#    1249             )
#    1250
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1464                 util.raise_from_cause(newraise, exc_info)
#    1465             elif should_wrap:
# -> 1466                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1467             else:
#    1468                 util.reraise(*exc_info)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     381     exc_type, exc_value, exc_tb = exc_info
#     382     cause = exc_value if exc_value is not exception else None
# --> 383     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     384
#     385
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     126             value.__cause__ = cause
#     127         if value.__traceback__ is not tb:
# --> 128             raise value.with_traceback(tb)
#     129         raise value
#     130
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1222                 if not evt_handled:
#    1223                     self.dialect.do_executemany(
# -> 1224                         cursor, statement, parameters, context
#    1225                     )
#    1226             elif not parameters and context.no_parameters:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     750             extras.execute_batch(cursor, statement, parameters)
#     751         else:
# --> 752             cursor.executemany(statement, parameters)
#     753
#     754     @util.memoized_instancemethod
#
# IntegrityError: (psycopg2.IntegrityError) duplicate key value violates unique constraint "pk_make"
# DETAIL:  Key (make)=(Acura) already exists.
#
# [SQL: INSERT INTO make (id, make) VALUES (%(id)s, %(make)s)]
# [parameters: ({'id': 1, 'make': 'Acura'}, {'id': 2, 'make': 'Alfa Romeo'}, {'id': 3, 'make': 'Aston Martin'}, {'id': 4, 'make': 'Audi'}, {'id': 5, 'make': 'BMW'}, {'id': 6, 'make': 'Bentley'}, {'id': 7, 'make': 'Buick'}, {'id': 8, 'make': 'Cadillac'}  ... displaying 10 of 40 total bound parameter sets ...  {'id': 40, 'make': 'Volkswagen'}, {'id': 41, 'make': 'Volvo'})]
# (Background on this error at: http://sqlalche.me/e/gkpj)

# %%
final_average_price_2015.to_sql(name = 'avg_price_2015', con = engine, if_exists = 'append', index = False)

# %%
final_average_price_2016.to_sql(name = 'avg_price_2016', con = engine, if_exists = 'append', index = False)

# %%
final_average_price_2017.to_sql(name = 'avg_price_2017', con = engine, if_exists = 'append', index = False)

# %% [markdown]
# # Visualization

# %%
# Import dependencies

import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# Out:
# Traceback (most recent call last):
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\cbook\__init__.py", line 215, in process
#     func(*args, **kwargs)
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\backends\backend_nbagg.py", line 236, in <lambda>
#     canvas.mpl_connect('close_event', lambda event: Gcf.destroy(num))
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\_pylab_helpers.py", line 54, in destroy
#     cls._activeQue.remove(manager)
# ValueError: list.remove(x): x not in list
# Traceback (most recent call last):
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\cbook\__init__.py", line 215, in process
#     func(*args, **kwargs)
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\backends\backend_nbagg.py", line 236, in <lambda>
#     canvas.mpl_connect('close_event', lambda event: Gcf.destroy(num))
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\_pylab_helpers.py", line 54, in destroy
#     cls._activeQue.remove(manager)
# ValueError: list.remove(x): x not in list
# Traceback (most recent call last):
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\cbook\__init__.py", line 215, in process
#     func(*args, **kwargs)
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\backends\backend_nbagg.py", line 236, in <lambda>
#     canvas.mpl_connect('close_event', lambda event: Gcf.destroy(num))
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\_pylab_helpers.py", line 54, in destroy
#     cls._activeQue.remove(manager)
# ValueError: list.remove(x): x not in list
# Traceback (most recent call last):
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\cbook\__init__.py", line 215, in process
#     func(*args, **kwargs)
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\backends\backend_nbagg.py", line 236, in <lambda>
#     canvas.mpl_connect('close_event', lambda event: Gcf.destroy(num))
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\_pylab_helpers.py", line 54, in destroy
#     cls._activeQue.remove(manager)
# ValueError: list.remove(x): x not in list
# Traceback (most recent call last):
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\cbook\__init__.py", line 215, in process
#     func(*args, **kwargs)
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\backends\backend_nbagg.py", line 236, in <lambda>
#     canvas.mpl_connect('close_event', lambda event: Gcf.destroy(num))
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\_pylab_helpers.py", line 54, in destroy
#     cls._activeQue.remove(manager)
# ValueError: list.remove(x): x not in list
# Traceback (most recent call last):
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\cbook\__init__.py", line 215, in process
#     func(*args, **kwargs)
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\backends\backend_nbagg.py", line 236, in <lambda>
#     canvas.mpl_connect('close_event', lambda event: Gcf.destroy(num))
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\_pylab_helpers.py", line 54, in destroy
#     cls._activeQue.remove(manager)
# ValueError: list.remove(x): x not in list
# Traceback (most recent call last):
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\cbook\__init__.py", line 215, in process
#     func(*args, **kwargs)
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\backends\backend_nbagg.py", line 236, in <lambda>
#     canvas.mpl_connect('close_event', lambda event: Gcf.destroy(num))
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\_pylab_helpers.py", line 54, in destroy
#     cls._activeQue.remove(manager)
# ValueError: list.remove(x): x not in list
# Traceback (most recent call last):
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\cbook\__init__.py", line 215, in process
#     func(*args, **kwargs)
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\backends\backend_nbagg.py", line 236, in <lambda>
#     canvas.mpl_connect('close_event', lambda event: Gcf.destroy(num))
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\_pylab_helpers.py", line 54, in destroy
#     cls._activeQue.remove(manager)
# ValueError: list.remove(x): x not in list
# Traceback (most recent call last):
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\cbook\__init__.py", line 215, in process
#     func(*args, **kwargs)
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\backends\backend_nbagg.py", line 236, in <lambda>
#     canvas.mpl_connect('close_event', lambda event: Gcf.destroy(num))
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\_pylab_helpers.py", line 54, in destroy
#     cls._activeQue.remove(manager)
# ValueError: list.remove(x): x not in list
# Traceback (most recent call last):
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\cbook\__init__.py", line 215, in process
#     func(*args, **kwargs)
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\backends\backend_nbagg.py", line 236, in <lambda>
#     canvas.mpl_connect('close_event', lambda event: Gcf.destroy(num))
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\_pylab_helpers.py", line 54, in destroy
#     cls._activeQue.remove(manager)
# ValueError: list.remove(x): x not in list
# Traceback (most recent call last):
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\cbook\__init__.py", line 215, in process
#     func(*args, **kwargs)
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\backends\backend_nbagg.py", line 236, in <lambda>
#     canvas.mpl_connect('close_event', lambda event: Gcf.destroy(num))
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\_pylab_helpers.py", line 54, in destroy
#     cls._activeQue.remove(manager)
# ValueError: list.remove(x): x not in list
# Traceback (most recent call last):
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\cbook\__init__.py", line 215, in process
#     func(*args, **kwargs)
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\backends\backend_nbagg.py", line 236, in <lambda>
#     canvas.mpl_connect('close_event', lambda event: Gcf.destroy(num))
#   File "C:\Users\YARA\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\_pylab_helpers.py", line 54, in destroy
#     cls._activeQue.remove(manager)
# ValueError: list.remove(x): x not in list

# %%
# Creating bar to represesnt all Makes manufactured in 2015 and their average price 

plt.figure(figsize = (20, 12))

y = final_average_price_2015["price"]
x = final_average_price_2015["make"]

plt.bar(x, y, color = "blue", alpha = 0.5, align = "center")

tick_locations = [value for value in x]
plt.xticks(tick_locations, rotation = 90, size = 15)

plt.xlim(-0.75, len(x) - 0.25)
plt.ylim(0, max(y) + 10000)

plt.title("AVG Price 2015", size = 25)
plt.xlabel("Make of car", size = 20)
plt.ylabel("Average Price", size = 20)


# plt.savefig("Images/AVG_price_2015.png")

plt.show()

# %%
# Creating bar to represesnt all Makes manufactured in 2016 and their average price 

plt.figure(figsize = (20, 12))

y = final_average_price_2016["price"]
x = final_average_price_2016["make"]

plt.bar(x, y, color = "red", alpha = 0.5, align = "center")

tick_locations = [value for value in x]
plt.xticks(tick_locations, rotation = 90, size = 15)

plt.xlim(-0.75, len(x) - 0.25)
plt.ylim(0, max(y) + 10000)

plt.title("AVG Price 2016", size = 25)
plt.xlabel("Make of car", size = 20)
plt.ylabel("Average Price", size = 20)

# plt.savefig("Images/AVG_price_2016.png")

plt.show()

# %%
# Creating bar to represesnt all Makes manufactured in 2017 and their average price 

plt.figure(figsize = (20, 12))

y = final_average_price_2017["price"]
x = final_average_price_2017["make"]

plt.bar(x, y, color = "grey", alpha = 0.5, align = "center")

tick_locations = [value for value in x]
plt.xticks(tick_locations, rotation = 90, size = 15)

plt.xlim(-0.75, len(x) - 0.25)
plt.ylim(0, max(y) + 10000)

plt.title("AVG Price 2017", size = 25)
plt.xlabel("Make of car", size = 20)
plt.ylabel("Average Price", size = 20)

# plt.savefig("Images/AVG_price_2017.png")

plt.show()

# %%
# Combined bar, that includes all 3 bars above

make_types = final_make["make"]
n_groups = 40
fig, ax = plt.subplots()
fig.set_size_inches((20, 12))
index = np.arange(n_groups)
bar_width = 0.25
opacity = 0.8

plt.bar(x = index, height = final_average_price_2015["price"], width = bar_width, color = "blue", label = "2015")

plt.bar(x = index + bar_width, height = final_average_price_2016["price"], width = bar_width, color = "red", label = "2016")

plt.bar(x = index + 2*bar_width, height = final_average_price_2017["price"], width = bar_width, color = "grey", label = "2017")

plt.title("Comparison of average price by make", size = 20)
plt.ylabel("Average Price", size = 15)
plt.xlabel("Make of car", size = 15)
plt.xticks(index + bar_width, make_types, rotation = 90, size = 15)
plt.legend(prop = {"size":15})

plt.tight_layout()

# plt.savefig("Images/Comparison_of_avg_price.png")

plt.show()

# %%
# ANOVA statistical test to check is it any significant difference between all average prices 

from scipy.stats import stats

stats.f_oneway(final_average_price_2015["price"], final_average_price_2016["price"], final_average_price_2017["price"])
# Out:
# F_onewayResult(statistic=0.326891463647351, pvalue=0.7218185154674215)
